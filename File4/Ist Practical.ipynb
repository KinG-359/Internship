# %% [markdown]
# # Dineout

# %%
pip install bs4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
import pandas as pd
import numpy as ny

# %%
from bs4 import BeautifulSoup
Soup=(Page.content)
Soup
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Wikipedia, the free encyclopedia</title>\n<script>document.documentElement.className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled";(function(){var cookie=document.cookie.match(/(?:^|; )enw
# ...

# %%
Page=requests.get('https://www.dineout.co.in/delhi-restaurants/buffet-special')
Page
# Out:
# <Response [200]>

# %%
first_title.text
# Out:
# 'Ministry Of Beer'

# %%
first_title
# Out:
# <a analytics-action="RestaurantCardClick" analytics-label="32381_Ministry Of Beer" class="restnt-name ellipsis" data-w-onclick="sendAnalyticsCommon|w1-restarant" href="/delhi/ministry-of-beer-connaught-place-central-delhi-32381">Ministry Of Beer</a>

# %%
loc=soup.find('a',class_="restnt-name ellipsis")
loc.text
# Out:
# 'Ministry Of Beer'

# %%
titles = []

for i in soup.find_all('a',class_="restnt-name ellipsis"):
    titles.append(i.text)
    
titles
# Out:
# ['Ministry Of Beer',
#  'Local',
#  'Tamasha',
#  'Station Bar',
#  'My Bar Square',
#  'Warehouse Cafe',
#  'Openhouse Cafe',
#  'The G.T. Road',
#  'The Junkyard Cafe',
#  'Lord of the Drinks',
#  'Unplugged Courtyard',
#  'Connaught Club House',
#  "Berco's",
#  'QBA',
#  'Connaught Club House',
#  '38 Barracks',
#  'Ardor 2.1 Restaurant and Lounge',
#  'Cafe High 5',
#  'Dasaprakash',
#  'The Imperial Spice',
#  'Somewhere Restaurant & Bar']

# %%
sta = soup.find('span',class_="double-line-ellipsis")
sta.text.split('|')[0]
# Out:
# '₹ 3,000 for 2 (approx) '

# %%
Price = []

for i in soup.find_all('span',class_="double-line-ellipsis"):
    Price.append(i.text.split('|')[0])
    
    
Price
# Out:
# ['₹ 3,000 for 2 (approx) ',
#  '₹ 2,000 for 2 (approx) ',
#  '₹ 2,000 for 2 (approx) ',
#  '₹ 1,100 for 2 (approx) ',
#  '₹ 2,000 for 2 (approx) ',
#  '₹ 2,500 for 2 (approx) ',
#  '₹ 2,000 for 2 (approx) ',
#  '₹ 2,000 for 2 (approx) ',
#  '₹ 2,100 for 2 (approx) ',
#  '₹ 2,500 for 2 (approx) ',
#  '₹ 3,300 for 2 (approx) ',
#  '₹ 1,800 for 2 (approx) ',
#  '₹ 1,300 for 2 (approx) ',
#  '₹ 2,100 for 2 (approx) ',
#  '₹ 2,100 for 2 (approx) ',
#  '₹ 2,700 for 2 (approx) ',
#  '₹ 2,000 for 2 (approx) ',
#  '₹ 1,700 for 2 (approx) ',
#  '₹ 800 for 2 (approx) ',
#  '₹ 3,000 for 2 (approx) ',
#  '₹ 1,000 for 2 (approx) ']

# %%
loc=soup.find('div',class_="restnt-loc ellipsis")
loc.text
# Out:
# 'M-Block,Connaught Place, Central Delhi'

# %%
Location = []

for i in soup.find_all('div',class_="restnt-loc ellipsis"):
    Location.append(i.text)
    
Location
# Out:
# ['M-Block,Connaught Place, Central Delhi',
#  'Scindia House,Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'F-Block,Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'M-Block,Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Janpath, Central Delhi',
#  'M-Block,Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi',
#  'M-Block,Connaught Place, Central Delhi',
#  'Connaught Place, Central Delhi']

# %%
Images = []

for i in soup.find_all('img',class_="no-img"):
    Images.append(i.get('data-src'))
Images
# Out:
# ['https://im1.dineout.co.in/images/uploads/restaurant/sharpen/3/a/d/p32381-1495943585592a49a166fe7.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/2/b/t/p27452-15020105505986dcb6d147f.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/2/a/j/p20996-145631488756cd9a0796608.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/9/i/b/p971-165909823762e3d47db6d56.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/1/m/i/p12709-15681189525d7798a8c5aa5.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/4/h/o/p420-15241335515ad86eaf373ce.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/1/j/y/p19748-16474299906231c96621c58.jpg?tr=tr:n-medium',
#  'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/3/m/u/p31393-15972091555f337a43bb961.jpg?tr=tr:n-medium',
# ...

# %%
print(len(titles),len(Location),len(Price),len(Images))
# Out:
# 21 21 21 21

# %%
import pandas as pd
df = pd.DataFrame({'Titles':titles,'Location':Location,'price':Price,'Images_url':Images})
df
# Out:
#                              Titles  \
# 0                  Ministry Of Beer
# 1                             Local
# 2                           Tamasha
# 3                       Station Bar
# 4                     My Bar Square
# 5                    Warehouse Cafe
# 6                    Openhouse Cafe
# 7                     The G.T. Road
# 8                 The Junkyard Cafe
# 9                Lord of the Drinks
# 10              Unplugged Courtyard
# 11             Connaught Club House
# 12                          Berco's
# 13                              QBA
# 14             Connaught Club House
# 15                      38 Barracks
# 16  Ardor 2.1 Restaurant and Lounge
# 17                      Cafe High 5
# 18                      Dasaprakash
# 19               The Imperial Spice
# 20       Somewhere Restaurant & Bar
#
#                                         Location                    price  \
# 0         M-Block,Connaught Place, Central Delhi  ₹ 3,000 for 2 (approx)
# ...

# %% [markdown]
# # Wikipedia

# %%
import requests
from bs4 import BeautifulSoup

# %%
import requests

# %%
page=requests.get('https://en.wikipedia.org/wiki/Main_Page')
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
Heading=soup.find('span',class_="mw-headline")
Heading
Heading.text
# Out:
# 'Welcome to Wikipedia'

# %%
Heading=soup.find_all('span',class_="mw-headline")
Heading
# Out:
# [<span class="mw-headline" id="Welcome_to_Wikipedia">Welcome to <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a></span>,
#  <span class="mw-headline" id="From_today's_featured_article">From today's featured article</span>,
#  <span class="mw-headline" id="Did_you_know_...">Did you know ...</span>,
#  <span class="mw-headline" id="In_the_news">In the news</span>,
#  <span class="mw-headline" id="On_this_day">On this day</span>,
#  <span class="mw-headline" id="From_today's_featured_list">From today's featured list</span>,
#  <span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span>,
#  <span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span>,
#  <span class="mw-headline" id="Wikipedia's_sister_projects">Wikipedia's sister projects</span>,
#  <span class="mw-headline" id="Wikipedia_languages">Wikipedia languages</span>]

# %%
Heading=[]
for i in soup.find_all('span',class_="mw-headline"):
    Heading.append(i.text)
    
Heading
# Out:
# ['Welcome to Wikipedia',
#  "From today's featured article",
#  'Did you know\xa0...',
#  'In the news',
#  'On this day',
#  "From today's featured list",
#  "Today's featured picture",
#  'Other areas of Wikipedia',
#  "Wikipedia's sister projects",
#  'Wikipedia languages']

# %%
print(len(Heading))
# Out:
# 10

# %%
import pandas as pd

# %%
df=pd.DataFrame({'Header_tags':Heading})
df
# Out:
#                      Header_tags
# 0           Welcome to Wikipedia
# 1  From today's featured article
# 2               Did you know ...
# 3                    In the news
# 4                    On this day
# 5     From today's featured list
# 6       Today's featured picture
# 7       Other areas of Wikipedia
# 8    Wikipedia's sister projects
# 9            Wikipedia languages
